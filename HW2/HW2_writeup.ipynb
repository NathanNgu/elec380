# %% [markdown]
# ## Problem 1A (10 pts)
#
# Poisson Correct percentage with 364 test trials: 0.9203296703296703, 0.9505494505494505, 0.9065934065934066, 0.9423076923076923, 0.945054945054945
#
# The range of values that I have observed over 5 trials is a fractional correctness from 0.9 to 0.95. The mean is 0.933
#
#
# After modifying the code with the above corrections,
# Poisson Correct percentage with 927 test trials:  0.9352750809061489, 0.8996763754045307, 0.9201725997842503, 0.9471413160733549, 0.9104638619201726
#
# The range of values that I have observed over 5 trials is a fractional correctness from 0.9 to 0.95. The mean is 0.922
#
# Based on the 5 trials tested, it looks like there is negligible change in variability or standard deviation in the poisson trials. However, it does seem like the original version with no specified window length had slightly higher fractional correctness than the window_length of 750ms

# %% [markdown]
# ## Problem 1B (20 pts) - How does the duration of the decoding window affect performance?
# As the size of the decoding window increases, the performance of the algorithm increases as well
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Problem 1C (20 pts) - Where should the plan window begin?
#
# Based upon the figure located below, it looks like the planning window should be located at around 100ms after the target appears. This seems to correlate with the highest level of decoding accuray with normal levels of error in the decoding.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Problem 2A (30 pts) - How does the number of neurons affect performance?
#
# Based upon the data in the graph below, it looks like around 90 neurons are needed in order to obtain an adequate level of decoding accuracy. With fewer neurons, the level of accuracy seems to rise steeply. With a greater number of neurons, the benefit to having more neurons seems to decrease. As a result, 90 neurons seems to hit a happy medium between enough neurons to obtain accurate calcualtions but not an extraneous amount of neurons to where there is negligible benefit
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## Problem 2B (20 pts) - How does firing rate change performance?
#
# Based upon the results located in the graph below, it looks like the most firing neurons outperformed the least firing neurons. However, a random set of neurons seemed to outperform the results of the most firing neurons. This tells us that a range of neurons with different levels of excitement are necessary to capture the full range of neuron activity
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## Problem 2C (20 pts extra credit). What is the minimum size of ensemble that will yield good performance?
#
# Based upon the data shown above, it looks like you need the middle 30 neurons in the firing rate distribution to match the decoding performance of a random set of 50 neurons. This is 60% of the total neurosn necessary to match the performance of a random set of 50 neurons
#
# No matter how many neurons are taken from the middle of the firing distribution, it does not seem to be possible to reach the level of accuracy of 100 or 150 random neurons.
#
# It seems like as the number of random neurons increases, it becomes harder and harder to match the level of randomness required to decode a random set of neurons with high accuracy. At a certain point, it becomes better to look at a random set of neurons rather than a specific set that "should" match the accuracy.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Problem 3 (20 pts extra credit)
#
# Decoding performance improves as the size of the training set increases, following a logarithmic trend. This improvement is due to the additional information available to the model, which enhances its ability to learn and make accurate predictions.
#
# ![image.png](attachment:image.png)
